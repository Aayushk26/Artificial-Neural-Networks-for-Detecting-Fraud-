# %%
# Importing our dataset and some necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
dataset=pd.read_csv('C:\\Users\\Aayush Kandpal\\Downloads\\P16-Self-Organizing-Maps\\Self_Organizing_Maps\\Credit_Card_Applications.csv')

# %%
dataset
# This dataset has the bank data of 690. The last column that is column 'Class' tells us weather the user comitted fraud or not.
# 0 represents that no fraud was comitted while 1 says that fraud was committed
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# 0    100  1213      0
# 1    160     1      0
# 2    280     1      0
# 3      0     1      1
# 4     60   159      1
# ..   ...   ...    ...
# 685    0     1      1
# 686    0    45      0
# 687  100     1      1
# 688  120    12      1
# 689  560     1      1
#
# [690 rows x 16 columns]

# %%
# Chekcing how many values we have . There are no missing values_Source
dataset.count()
# Out:
# CustomerID    690
# A1            690
# A2            690
# A3            690
# A4            690
# A5            690
# A6            690
# A7            690
# A8            690
# A9            690
# A10           690
# A11           690
# A12           690
# A13           690
# A14           690
# Class         690
# dtype: int64

# %%
# plotting a correlation matrix for our dataset 
matrix=dataset.corr()
fig,ax=plt.subplots(figsize=(10,6))
sns.heatmap(matrix,vmax=0.8,square=True)

# %%
# Getting all the correlation data
corr = dataset.corr()
print (corr['Class'].sort_values(ascending=False)[:], '\n')
# Out:
# Class         1.000000
# A8            0.720407
# A9            0.458301
# A10           0.406410
# A5            0.373712
# A7            0.322475
# A6            0.246567
# A3            0.206294
# A4            0.194306
# A14           0.175657
# A2            0.161626
# A12           0.115261
# CustomerID    0.035400
# A11           0.031625
# A1           -0.013897
# A13          -0.099972
# Name: Class, dtype: float64

# %%
# Splitting our data intot test and train. In total we have bank details of 690 users out of which we will train our Artificial 
 # Network on 80% data and 20 % data we will test our networks accuracy
x=dataset.drop(['A13','A1','CustomerID','A11','A6','A3','A4','A14','A2','A12'],axis=1)  
# I have tried multiple variations of features based on correlation I have only been able to achieve 89.13 percent accuracy.

x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
# Some plots from the dataset to see the skew of features that are multivariate
# A2,A3,

print ("Skew is:", dataset.A2.skew())

plt.hist(dataset.A2,bins=100)
plt.xlabel
plt.show()

print ("Skew is:", dataset.A3.skew())

plt.hist(dataset.A3,bins=100)
plt.xlabel
plt.show()

print ("Skew is:", dataset.A7.skew())

plt.hist(dataset.A7,bins=100)
plt.xlabel
plt.show()

print ("Skew is:", dataset.A10.skew())

plt.hist(dataset.A10,bins=100)
plt.xlabel
plt.show()

print ("Skew is:", dataset.A13.skew())

plt.hist(dataset.A13,bins=100)
plt.xlabel
plt.show()

print ("Skew is:", dataset.A14.skew())

plt.hist(dataset.A14,bins=100)
plt.xlabel
plt.show()
# Out:
# Skew is: 1.1559350076287465
# Skew is: 1.4888131246649208
# Skew is: 2.891330424153805
# Skew is: 5.152519857445983
# Skew is: 2.7499117491023255
# Skew is: 13.140655014445455

# %%
import warnings
warnings.filterwarnings("ignore")

fig, ax = plt.subplots(nrows=4, ncols=3, figsize=(20,12))
plt.subplots_adjust(hspace=0.5)



a2=dataset.A2
ax[0,1].set_title("A2")
ax[0,1].plot(a2)
ax[0,1].legend(loc='best')

a3=dataset.A3
ax[0,2].set_title("A3")
ax[0,2].plot(a3)
ax[0,2].legend(loc='best')

a4=dataset.A4
ax[1,0].set_title("A4")
ax[1,0].plot(a4)
ax[1,0].legend(loc='best')

a5=dataset.A5
ax[1,1].set_title("A5")
ax[1,1].plot(a5)
ax[1,1].legend(loc='best')

a6=dataset.A6
ax[1,2].set_title("A6")
ax[1,2].plot(a6)
ax[1,2].legend(loc='best')

a7=dataset.A7
ax[2,0].set_title("A7")
ax[2,0].plot(a7)
ax[2,0].legend(loc='best')

a8=dataset.A8
ax[2,1].set_title("A8")
ax[2,1].plot(a8)
ax[2,1].legend(loc='best')

a9=dataset.A9
ax[2,2].set_title("A9")
ax[2,2].plot(a9,)
ax[2,2].legend(loc='best')

a10=dataset.A10
ax[3,0].set_title("A10")
ax[3,0].plot(a10)
ax[3,0].legend(loc='best')

a11=dataset.A11
ax[3,1].set_title("A11")
ax[3,1].plot(a11)
ax[3,1].legend(loc='best')

a12=dataset.A12
ax[3,2].set_title("A12")
ax[3,2].plot(a12)
ax[3,2].legend(loc='best')

a13=dataset.A13
ax[0,0].set_title("A13")
ax[0,0].plot(a13)
ax[0,0].legend(loc='best')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
# Most correlated fetaure feature A8
print ("Skew is:", dataset.A8.skew())

plt.hist(dataset.A8,bins=100)
plt.xlabel
plt.show()
# Out:
# Skew is: -0.0930559498550084

# %%
# Feature scaling so that one feature does not have greater weight on the results
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler(feature_range=(0,1))
xtrain=sc.fit_transform(x_train)
xtest=sc.transform(x_test)

# %%
# Importing some libraries to buikd our ANN
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
# Adding the input layer and the first hidden layer with dropout
# Take average of input + output for units/output_dim param in Dense
# input_dim is necessary for the first layer as it was just initialized
classifier=Sequential()

# Hidden Layer 1 with dropout regularisation set at 20 percent
classifier.add(Dense(10, input_dim = 15, kernel_initializer = 'uniform', activation = 'relu' ))
classifier.add(Dropout( 0.2))
# hidden Layer 2 with dropout regularisation set at 20 percent
classifier.add(Dense(10, kernel_initializer = 'uniform', activation = 'relu' ))
classifier.add(Dropout( 0.2))
# Hidden Layer 3 with dropout regularisation set at 20 percent
classifier.add(Dense(10, kernel_initializer = 'uniform', activation = 'relu' ))
classifier.add(Dropout( 0.2))
# Hidden Layer 4 with dropout regularisation set at 20 percent
classifier.add(Dense(10, kernel_initializer = 'uniform', activation = 'relu' ))

# Final output layer 
classifier.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid' ))
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Fitting the ANN to the Training Set
# x_train, y_train, Batch size, Epochs (whole training set)
classifier.fit(xtrain, y_train, batch_size = 12, epochs = 10)
# Out:
# Epoch 1/10
# 46/46 [==============================] - 0s 846us/step - loss: 0.6928 - accuracy: 0.5543
# Epoch 2/10
# 46/46 [==============================] - 0s 911us/step - loss: 0.6916 - accuracy: 0.5616
# Epoch 3/10
# 46/46 [==============================] - 0s 867us/step - loss: 0.6893 - accuracy: 0.5616
# Epoch 4/10
# 46/46 [==============================] - 0s 933us/step - loss: 0.6634 - accuracy: 0.5616
# Epoch 5/10
# 46/46 [==============================] - 0s 867us/step - loss: 0.5754 - accuracy: 0.5616
# Epoch 6/10
# 46/46 [==============================] - 0s 932us/step - loss: 0.5228 - accuracy: 0.5616
# Epoch 7/10
# 46/46 [==============================] - 0s 889us/step - loss: 0.4999 - accuracy: 0.7953
# Epoch 8/10
# 46/46 [==============================] - 0s 867us/step - loss: 0.5012 - accuracy: 0.8496
# Epoch 9/10
# 46/46 [==============================] - 0s 889us/step - loss: 0.4952 - accuracy: 0.8225
# Epoch 10/10
# 46/46 [==============================] - 0s 846us/step - loss: 0.4758 - accuracy: 0.8116

# %%
# Predicting the Test set results
# Note that the output we have got are the probabilities of potential fraud 
# Any probability greater than 50 percent or 0.5 will be considered as 1 and the less than that will be converted to 0
y_pred = classifier.predict(xtest)
y_pred = (y_pred > 0.5)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
# Plotting our confusion matrix
plt.matshow(cm)
plt.show() 
cm
# See the array below for better understanding
# Out:
# array([[65,  8],
#        [ 7, 58]], dtype=int64)

# %%
 # As you can see we were successfully able to predict fraud with almost 90 percent accuracy, which is a pretty good result.
    # Upvote if you liked this Artificial neural network model
from sklearn.metrics import accuracy_score
print('Accuracy Score:',accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score: 0.8913043478260869

# %%
# We have achieved a good precison, recall and f1 score with our model
# Thanks
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90        73
#            1       0.88      0.89      0.89        65
#
#     accuracy                           0.89       138
#    macro avg       0.89      0.89      0.89       138
# weighted avg       0.89      0.89      0.89       138

# %%
 # Hence we have obtained an accuracy of about 90 percent in successfully predicting Credit card fraud based on bank details.
